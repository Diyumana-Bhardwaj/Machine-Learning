# %% [markdown]
# # ***Matplotlib Tutorial***

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
print(matplotlib.__version__)
# Out:
# 3.8.0

# %%
x_axis=np.random.randint(6,size=(10))
y_axis=np.random.randint(250,size=(10))
print(x_axis)
print(y_axis)
plt.plot(x_axis,y_axis)
plt.show()
# Out:
# [4 3 4 1 1 3 0 4 0 2]
# [101 177  91 131 231 208 194 220 163  11]

# %%
x=np.sort(x_axis)
y=np.sort(y_axis)
plt.plot(x,y)
plt.show()

# %%
plt.plot(x_axis)
plt.show()

# %% [markdown]
# **Marker**
#
# ---
#
#
# 'o'	Circle
# '*'	Star
# '.'	Point
# ','	Pixel
# 'x'	X
# 'X'	X (filled)
# '+'	Plus
# 'P'	Plus (filled)
# 's'	Square
# 'D'	Diamond
# 'd'	Diamond (thin)
# 'p'	Pentagon
# 'H'	Hexagon
# 'h'	Hexagon
# 'v'	Triangle Down
# '^'	Triangle Up
# '<'	Triangle Left
# '>'	Triangle Right
# '1'	Tri Down
# '2'	Tri Up
# '3'	Tri Left
# '4'	Tri Right
# '|'	Vline
# '_'	Hline

# %%
plt.plot(y_axis)
plt.show()

# %%
plt.plot(y_axis,marker='o')
plt.show()

# %%
plt.plot(y_axis,marker='4')
plt.show()

# %% [markdown]
# **Line Reference**
#
# ---
#
#
#
# '-'	Solid line
# ':'	Dotted line
# '--'	Dashed line
# '-.'	Dashed/dotted line

# %%
plt.plot(y_axis,':')
plt.show()

# %% [markdown]
# **Color Reference**
#
#
# ---
#
#
# 'r'	Red
# 'g'	Green
# 'b'	Blue
# 'c'	Cyan
# 'm'	Magenta
# 'y'	Yellow
# 'k'	Black
# 'w'	White

# %%
plt.plot(y_axis,'m')
plt.show()

# %% [markdown]
# **Format Strings fmt**
#
# You can also use the shortcut string notation parameter to specify the marker.
#
# This parameter is also called fmt, and is written with this syntax:
#
# **marker|line|color**

# %%
plt.plot(y_axis,'*--y')
plt.show()

# %% [markdown]
# **Marker Size as ms**

# %%
plt.plot(y_axis,'*--m',ms=20)
plt.show()

# %% [markdown]
# **markeredgecolor**
#
# change edge color using mec

# %%
y= [0,1,1,2,2,3,3,4,3,3,2,2,1,1,0]
x=[1,3,2,4,3,5,4,6,8,7,9,8,10,9,11]
plt.plot(x,y,'*-g',ms=15,mec='r')
plt.show()

# %% [markdown]
# **makefacecolor**
#
# maker color change using mfc

# %%
y= [0,1,1,2,2,3,3,4,3,3,2,2,1,1,0]
x=[1,3,2,4,3,5,4,6,8,7,9,8,10,9,11]
plt.plot(x,y,'*-g',ms=15,mfc='r',mec='r')
plt.show()

# %% [markdown]
# plt.plot(ypoints, marker = 'o', ms = 20, mec = '#4CAF50', mfc = '#4CAF50')
#
# https://www.w3schools.com/colors/colors_hexadecimal.asp
#
# plt.plot(ypoints, marker = 'o', ms = 20, mec = 'hotpink', mfc = 'hotpink')
#
# https://www.w3schools.com/colors/colors_names.asp

# %% [markdown]
# ###**MATPLOTLIB LINES**
#
# 'solid' (default)	'-'
# 'dotted'	':'
# 'dashed'	'--'
# 'dashdot'	'-.'
# 'None'	'' or ' '

# %%
#LineStyle as ls
ypoints=np.array([3,8,1,10])

plt.plot(ypoints,ls='dotted')
plt.show()

# %%
plt.plot(ypoints,'hotpink',ls='dashed')
# plt.plot(ypoints,color='k',ls='dashed')
plt.show()

# %% [markdown]
# **Line Width**

# %%
plt.plot(ypoints,'hotpink',lw='20')
plt.show()

# %% [markdown]
# **axis range**

# %%
plt.plot(ypoints)
plt.axis([0,12,0,4])
plt.show()

# %%
plt.plot(ypoints)
plt.axis([0,4,0,12])
plt.show()

# %% [markdown]
# **Multiple lines**

# %%
y2=np.array([6,2,7,4])
plt.plot(ypoints)
plt.plot(y2)
plt.show()

# %%
x1=[1,3,5,7]
x2=[2,4,6,9]
plt.plot(x1,ypoints)
plt.plot(x2,y2)
plt.show()

# %%
# method 2
plt.plot(x1,ypoints,x2,y2)
plt.show()

# %% [markdown]
# ###**Matplotlib Labels and Title**
#
# **Create Labels for a Plot**
#
# With Pyplot, you can use the xlabel() and ylabel() functions to set a label for the x- and y-axis.
#
# **Create a Title for a Plot**
#
# With Pyplot, you can use the title() function to set a title for the plot.
#
# **Set Font Properties for Title and Labels**
#
# You can use the fontdict parameter in xlabel(), ylabel(), and title() to set font properties for the title and labels.
#
# **Position the Title**
#
# You can use the loc parameter in title() to position the title.
#
# Legal values are: 'left', 'right', and 'center' and for x axis 'top; 'bottom' and 'center' . Default value is 'center'.

# %%
x=[1,2,3,4,5,6,7,8,9]
Y1=[1,3,5,3,1,3,5,3,1]
y_axis=[2,4,6,4,2,4,6,4,2]
plt.plot(x,Y1,label="line L")
plt.plot(x,y_axis,label="line H")

plt.xlabel(" x axis")
plt.ylabel(" y axis")
plt.title("Line Graph Example")
plt.legend()
plt.show()

# %% [markdown]
# **Positioning of the legend**
#
# * upper left
# * upper right
# * lower left
# * lower right
# * upper centre
# * lower centre
# * centre left
# * centre right
# * centre

# %%
plt.plot(x,Y1,label="line L")
plt.plot(x,y_axis,label="line H")

plt.xlabel(" x axis")
plt.ylabel(" y axis")
plt.title("Line Graph Example")
plt.legend(loc='upper center')
plt.show()

# %% [markdown]
# **Change background color of the legend**
#
# using set_facecolor()

# %%
plt.plot(x,Y1,label="line L")
plt.plot(x,y_axis,label="line H")

plt.xlabel(" x axis")
plt.ylabel(" y axis")
plt.title("Line Graph Example")
plt.legend(loc="center",labelcolor="red",fontsize="xx-large")
plt.show()

# %%
plt.plot(x1,ypoints,x2,y2)
plt.xlabel("average speed")
plt.ylabel("average velocity")
plt.show()

# %%
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.plot(x1,ypoints,x2,y2)
plt.xlabel("average speed",fontdict=font1)
plt.ylabel("average velocity",fontdict=font2)
plt.show()

# %%
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.plot(x1,ypoints,x2,y2)
plt.xlabel("average speed",fontdict=font1,loc='left')
plt.ylabel("average velocity",fontdict=font2,loc='top')
plt.show()

# %%
#add grid
plt.plot(x1,ypoints,x2,y2)
plt.xlabel("average speed")
plt.ylabel("average velocity")
plt.grid()
plt.show()

# %%
#specific grid
plt.plot(x1,ypoints,x2,y2)
plt.xlabel("average speed")
plt.ylabel("average velocity")
plt.grid(axis='y')
plt.show()

# %% [markdown]
# **Set Line Properties for the Grid**
#
# You can also set the line properties of the grid, like this: grid(color = 'color', linestyle = 'linestyle', linewidth = number).

# %%
plt.plot(x1,ypoints,x2,y2)
plt.xlabel("average speed")
plt.ylabel("average velocity")
plt.grid(axis='y',color='m',linestyle='-.')
plt.show()

# %% [markdown]
# Matplotlib subplot

# %%
#plot 1:
x_plot1 = np.array([0, 1, 2, 3])
y_plot1 = np.array([3, 8, 1, 10])

#plot 2:
x_plot2 = np.array([0, 1, 2, 3])
y_plot2 = np.array([10, 20, 30, 40])

# %%
plt.subplot(1,2,1)
plt.plot(x_plot1,y_plot1)

plt.subplot(1,2,2)
plt.plot(x_plot2,y_plot2)

# %%
plt.subplot(2,2,1)
plt.plot(x_plot1,y_plot1)

plt.subplot(2,2,2)
plt.plot(x_plot2,y_plot2)

plt.subplot(2,2,3)
plt.plot(x_plot1,y_plot2)

plt.subplot(2,2,4)
plt.plot(x_plot2,y_plot1)

# %%
plt.subplot(2,1,1)
plt.plot(x_plot1,y_plot1)

plt.subplot(2,1,2)
plt.plot(x_plot2,y_plot2)

# %%
x11 = np.array([0, 1, 2, 3])
y11 = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x11,y11)
plt.title("SALES")

x12 = np.array([0, 1, 2, 3])
y12 = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x12,y12)
plt.title("INCOME")

x13 = np.array([0, 1, 2, 3])
y13 = np.array([6, 4, 1, 9])

plt.subplot(2, 3, 3)
plt.plot(x13,y13)
plt.title("PROFIT")

x14 = np.array([0, 1, 2, 3])
y14 = np.array([10, 30, 2, 4])

plt.subplot(2, 3, 4)
plt.plot(x14,y14)
plt.title("LOSE")

x = np.array([0, 1, 2, 3])
y = np.array([1, 3, 10, 8])

plt.subplot(2, 3, 5)
plt.plot(x,y)
plt.title("SAVINGS")

plt.subplots_adjust(hspace=0.5)
plt.subplots_adjust(wspace=0.5)

# plt.subplot(2, 3, 6)
# plt.plot(x,y)

# this will give error
# plt.subplot(2, 3, 7)
# plt.plot(x,y)

plt.show()

# %% [markdown]
# ### **Matplotlib Scatter**

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %% [markdown]
# **Compare Plots**

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %% [markdown]
# **coloring**

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y,color='hotpink')

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y,color = '#88c999')

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors)

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x,y,marker="*",s=50)
plt.show()

# %%
arrX = np.random.randint(100, size=(100))
arrY = np.random.randint(100, size=(100))

# Get all available colormaps
colormaps = plt.colormaps()


for i, cmap in enumerate(colormaps):
  plt.scatter(arrX,arrY,c=arrX, cmap=cmap)
  plt.title(cmap)
  plt.colorbar()
  plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
arrX = np.random.randint(100, size=(100))
arrY = np.random.randint(100, size=(100))
sizes=arrY

plt.scatter(arrX,arrY,s=sizes)
plt.show()

# %%
arrX = np.random.randint(100, size=(100))
arrY = np.random.randint(100, size=(100))
sizes=np.random.randint(300, size=(100))

plt.scatter(arrX,arrY,s=sizes)
plt.show()

# %% [markdown]
# TRANSPACENCY USING APLHA

# %%
arrX = np.random.randint(100, size=(100))
arrY = np.random.randint(100, size=(100))
sizes=np.random.randint(1000, size=(100))
colors=np.random.randint(100, size=(100))

plt.scatter(arrX,arrY,s=sizes,alpha=0.5,c=colors,cmap='nipy_spectral')
plt.show()

# %%
X1=np.linspace(0.0,5.0)
X2=np.linspace(0.0,2.0)

Y1=np.cos(2*np.pi*X1)*np.exp(-X1)
Y2=np.cos(2*np.pi*X2)

plt.subplot(2,1,1)
plt.plot(X1,Y1,'o-')
plt.ylabel("Damped osillation")

plt.subplot(2,1,2)
plt.plot(X2,Y2,'.-')
plt.ylabel("Undamped osillation")

plt.show()

# %% [markdown]
# **Matplotlib Bars**

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y,color="hotpink",width=0.5)
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x,y,color="aquamarine",height=0.5,edgecolor='m',linewidth=2,linestyle='-.')
plt.show()

# %%
z=[7,1,9,4]
w=[6,4,3,2]
plt.bar(x,y)
plt.bar(x,z,bottom=y)
plt.bar(x,w,bottom=y+z)
plt.show()

# %%
index=np.arange(len(x))
plt.bar(index,y,width=0.3,color="aquamarine")
plt.bar(index+0.3,z,width=0.3,color="hotpink")
plt.bar(index+0.6,w,width=0.3,color='yellow')
plt.xticks(index+0.3,["A",'B',"c",'D'])
plt.show()

# %% [markdown]
# **Matplotlib Histograms**

# %%
heights=np.array([
    164.66, 156.57, 163.66, 177.03, 189.51, 175.64, 141.31, 173.09, 197.30, 199.86,
    151.70, 172.49, 177.92, 166.21, 170.62, 168.07, 160.68, 182.24, 179.99, 169.99,
    143.97, 148.35, 186.99, 185.26, 179.24, 176.25, 157.61, 199.43, 174.30, 172.10,
    172.54, 167.01, 173.25, 140.31, 195.41, 161.53, 191.02, 180.20, 190.50, 157.52,
    148.77, 170.10, 191.77, 176.08, 145.93, 182.98, 167.45, 193.58, 192.28, 165.33,
    160.55, 191.45, 164.02, 194.91, 195.19, 194.35, 150.41, 163.93, 147.69, 167.85,
    153.92, 148.54, 157.14, 159.26, 144.62, 179.72, 151.15, 187.40, 166.73, 162.49,
    195.51, 193.02, 178.67, 181.68, 190.45, 170.11, 151.63, 179.68, 195.15, 163.05,
    171.29, 145.99, 184.58, 191.46, 149.41, 191.09, 184.49, 196.22, 175.91, 145.47,
    180.52, 191.95, 171.14, 166.56, 198.85, 153.21, 163.31, 178.88, 165.36, 184.23
])
plt.hist(heights,edgecolor='y')
plt.show()

# %%
bins=[140,160,180,200]
plt.hist(heights,bins,rwidth=0.9)
plt.show()

# %%
plt.hist(heights,histtype='step')
plt.show()

# %%
plt.hist(heights,orientation='horizontal',color='hotpink')
plt.show()

# %%
weights=[
    42.78, 95.12, 63.59, 51.47, 76.35, 83.21, 55.43, 68.97, 72.56, 48.23,
    61.34, 88.76, 70.21, 66.54, 49.78, 75.43, 81.26, 62.98, 45.12, 54.67,
    59.31, 79.45, 85.37, 67.82, 60.19, 72.34, 89.61, 56.42, 77.45, 47.89,
    52.68, 74.25, 92.14, 63.18, 58.24, 87.12, 71.96, 44.78, 82.56, 69.32,
    65.24, 61.85, 50.42, 78.21, 96.57, 53.87, 64.19, 46.74, 80.36, 57.13,
    49.65, 90.41, 55.72, 71.58, 73.34, 62.15, 79.12, 51.27, 84.69, 59.84,
    67.29, 76.45, 85.91, 66.42, 45.85, 60.74, 68.13, 54.96, 93.21, 88.59,
    64.35, 58.47, 77.82, 48.13, 52.67, 82.45, 91.18, 57.96, 70.85, 44.37,
    81.24, 55.98, 89.76, 63.41, 46.89, 75.82, 73.21, 53.45, 90.67, 62.41,
    56.24, 86.31, 47.65, 78.95, 60.31, 69.84, 72.58, 83.47
]
plt.hist(heights,color='hotpink')
plt.hist(weights,color="aquamarine")
plt.show()

# %%
arr1=[23, 58, 84, 6, 97, 19, 34, 62, 50, 73, 41, 14, 91, 11, 47, 76, 38, 70, 4, 89, 56, 95, 7, 18, 80, 27, 3, 49, 72, 60,
 21,85, 64, 25, 9, 45, 99, 32, 16, 68, 53, 88, 81, 30, 63, 40, 20, 13, 37, 77]

arr2=[15, 90, 42, 8, 65, 31, 78, 24, 66, 87, 28, 5, 92, 35, 83, 46, 36, 74, 1, 71, 57, 98, 12, 22, 26, 93, 75, 2, 10, 61,29, 94, 17, 44, 54, 67, 33, 79, 48, 86, 82, 43, 59, 39, 55, 6, 100, 52, 11, 69]
plt.hist(arr1,color='hotpink')
plt.hist(arr2,color='yellow',alpha=0.8)
plt.show()

# %%
plt.hist([arr1,arr2],color=['hotpink','yellow'])
plt.show()

# %% [markdown]
# changing size of chat

# %%
plt.figure(figsize=(16,9))
plt.hist([arr1,arr2],color=['hotpink','yellow'])
plt.show()

# %% [markdown]
# changing background color
#
# can be done using from matplotlib import style

# %% [markdown]
# ---
#
#
# **Pie Chart**
#
# As you can see the pie chart draws one piece (called a wedge) for each value in the array .
#
# By default the plotting of the first wedge starts from the x-axis and moves counterclockwise

# %%
plt.pie(y,labels=["Apples", "Bananas", "Cherries", "Dates"])
plt.show()

# %%
plt.pie(y,labels=["Apples", "Bananas", "Cherries", "Dates"],startangle=90)
plt.show()

# %%
plt.pie(y,labels=["Apples", "Bananas", "Cherries", "Dates"],startangle=180)
plt.show()

# %% [markdown]
# Explode
#
# Maybe you want one of the wedges to stand out? The explode parameter allows you to do that.
#
# The explode parameter, if specified, and not None, must be an array with one value for each wedge.

# %%
plt.pie(y,labels=["Apples", "Bananas", "Cherries", "Dates"],explode=[0.5,0,0,0.2])
plt.show()

# %%
plt.pie(y,labels=["Apples", "Bananas", "Cherries", "Dates"],explode=[0.2,0,0,0],shadow=True)
plt.show()

# %%
mycolors = ["black", "hotpink", "b", "#4CAF50"]
plt.pie(y,labels=["Apples", "Bananas", "Cherries", "Dates"],explode=[0.2,0,0,0],shadow=True,colors=mycolors)
plt.show()

# %% [markdown]
# **Legend**
#
# To add a list of explanation for each wedge, use the legend() function

# %%
y = np.array([3, 8, 1, 10])
mylabels=["Apples", "Bananas", "Cherries", "Dates"]
plt.pie(y,labels=mylabels,autopct="%0.1f%%")
plt.legend(title='Fruits chat:',loc="center")
plt.show()

# %%
y = np.array([3, 8, 1, 10])
mylabels=["Apples", "Bananas", "Cherries", "Dates"]
plt.pie(y,labels=mylabels,autopct="%0.1f%%",pctdistance=0.8,radius=1.5,labeldistance=1.1,rotatelabels=True)
plt.legend(title='Fruits chat:',loc="center")
plt.show()

# %%
y = np.array([3, 8, 1, 10])
colors=["m","yellow","red","aquamarine"]
ex=[0,0,0.3,0]
mylabels=["Apples", "Bananas", "Cherries", "Dates"]
plt.pie(y,colors=colors,labels=mylabels,autopct="%0.1f%%",explode=ex,frame=True)
# plt.legend(title='Fruits chat:',loc="center")
plt.show()

# %%
y = np.array([3, 8, 1, 10])
colors=["m","yellow","red","aquamarine"]
ex=[0,0,0.3,0]
mylabels=["Apples", "Bananas", "Cherries", "Dates"]
plt.pie(y,colors=colors,labels=mylabels,autopct="%0.1f%%",explode=ex,center=(4,7))
# plt.legend(title='Fruits chat:',loc="center")
plt.show()

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

# %%
#plotting a point
fig = plt.figure()
ax = plt.axes(projection='3d')
plt.scatter(3,4,5)
plt.show()

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

z = np.linspace(0, 1, 100)
x = z * np.sin(25 * z)
y = z * np.cos(25 * z)

# plotting
ax.plot3D(x, y, z, 'green')
ax.set_title('3D line plot geeks for geeks')
plt.show()

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

z = np.linspace(0, 1, 100)
x = z * np.sin(25 * z)
y = z * np.cos(25 * z)
c = x + y
ax.scatter(x, y, z, c = c)

plt.show()

# %%
x = np.outer(np.linspace(-2, 2, 10), np.ones(10))
y = x.copy().T
z = np.cos(x ** 2 + y ** 3)

fig = plt.figure()

# syntax for 3-D plotting
ax = plt.axes(projection='3d')

# syntax for plotting
ax.plot_surface(x, y, z, cmap='viridis',edgecolor='green')
ax.set_title('Surface plot geeks for geeks')
plt.show()

# %%
# x and y axis
x = np.linspace(-1, 5, 10)
y = np.linspace(-1, 5, 10)

X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(x ** 2 + y ** 2))

fig = plt.figure()
ax = plt.axes(projection ='3d')
ax.plot_wireframe(X, Y, Z, color ='green')
ax.set_title('wireframe geeks for geeks');
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-e6bc2bc8ac87> in <cell line: 10>()
#       8 fig = plt.figure()
#       9 ax = plt.axes(projection ='3d')
# ---> 10 ax.plot_wireframe(X, Y, Z, color ='green')
#      11 ax.set_title('wireframe geeks for geeks');
#
# /usr/local/lib/python3.10/dist-packages/mpl_toolkits/mplot3d/axes3d.py in plot_wireframe(self, X, Y, Z, **kwargs)
#    1859         had_data = self.has_data()
#    1860         if Z.ndim != 2:
# -> 1861             raise ValueError("Argument Z must be 2-dimensional.")
#    1862         # FIXME: Support masked arrays
#    1863         X, Y, Z = np.broadcast_arrays(X, Y, Z)
#
# ValueError: Argument Z must be 2-dimensional.

# %%
def f(x, y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))

# x and y axis
x = np.linspace(-1, 5, 10)
y = np.linspace(-1, 5, 10)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

fig = plt.figure()
ax = plt.axes(projection ='3d')
ax.plot_wireframe(X, Y, Z, color ='green')
ax.set_title('wireframe geeks for geeks');

# %%
def function(x, y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))


x = np.linspace(-10, 10, 40)
y = np.linspace(-10, 10, 40)

X, Y = np.meshgrid(x, y)
Z = function(X, Y)

fig = plt.figure(figsize=(10, 8))
ax = plt.axes(projection='3d')

ax.plot_surface(X, Y, Z, cmap='cool', alpha=0.8)

ax.set_title('3D Contour Plot of function(x, y) =\
                sin(sqrt(x^2 + y^2))', fontsize=14)
ax.set_xlabel('x', fontsize=12)
ax.set_ylabel('y', fontsize=12)
ax.set_zlabel('z', fontsize=12)

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.tri import Triangulation

def f(x, y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)
X, Y = np.meshgrid(x, y)
Z = f(X, Y)

tri = Triangulation(X.ravel(), Y.ravel())

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

ax.plot_trisurf(tri, Z.ravel(), cmap='cool', edgecolor='none', alpha=0.8)

ax.set_title('Surface Triangulation Plot of f(x, y) =\
                sin(sqrt(x^2 + y^2))', fontsize=14)
ax.set_xlabel('x', fontsize=12)
ax.set_ylabel('y', fontsize=12)
ax.set_zlabel('z', fontsize=12)

plt.show()

# %%
R = 2

# Define the Möbius strip surface
u = np.linspace(0, 2*np.pi, 100)
v = np.linspace(-1, 1, 100)
u, v = np.meshgrid(u, v)
x = (R + v*np.cos(u/2)) * np.cos(u)
y = (R + v*np.cos(u/2)) * np.sin(u)
z = v * np.sin(u/2)

# Create the plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the Möbius strip surface
ax.plot_surface(x, y, z, alpha=0.5)

# Set plot properties
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('Möbius Strip')

# Set the limits of the plot
ax.set_xlim([-3, 3])
ax.set_ylim([-3, 3])
ax.set_zlim([-3, 3])

# Show the plot
plt.show()

# %% [markdown]
# save fig can be done as plt.savefig("png_name")
